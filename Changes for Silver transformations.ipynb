# %% [markdown]
# ### Product Table changes
# -  Change data type for "Standard Cost" from string to int
# - 7 duplicates
# - "Color"  -> Multi and MULTI , Red and RED, Yellow and YELLOW
# - "Subcategory" -> Wheels and Whels
# - $ symbol
#
# ### Region Table changes
# - "Country" -> USA and United States
